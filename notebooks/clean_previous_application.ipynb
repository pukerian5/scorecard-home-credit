# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import my_modules.missing as ms
import warnings
warnings.filterwarnings('ignore')

# %%
prev_app = pd.read_csv('home-credit-default-risk/previous_application.csv')

# %%
pd.set_option('display.max_columns', None)

display(prev_app.sample(10))
print(f'Previous Application data contains:\n{prev_app.shape[0]} rows and {prev_app.shape[1]} columns')
print(f'\Previous Application data information:\n')
print(prev_app.info())
print(f'\nStatistical Summary of numerical columns:\n')

numerical = prev_app.select_dtypes(include='number')
display(numerical.describe())

categorical = prev_app.select_dtypes(include='object')
display(categorical.describe())
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 441106      2292606      286367     Consumer loans    37685.520
# 737587      1309258      253755     Consumer loans     2775.240
# 154187      1404481      363653         Cash loans          NaN
# 1056681     1648916      372881         Cash loans    26611.155
# 1026385     2632348      358471     Consumer loans     4889.025
# 828318      2217888      148211         Cash loans          NaN
# 321206      2079896      310799     Consumer loans     3947.580
# 367050      2576744      179624         Cash loans          NaN
# 1320802     1649616      102452         Cash loans          NaN
# 1364026     2417515      275433     Consumer loans     6718.770
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 441106        702000.000    645300.0         70200.000       702000.000
# 737587         27759.015     24979.5          2779.515        27759.015
# 154187             0.000         0.0               NaN              NaN
# 1056681       270000.000    284611.5               NaN       270000.000
# 1026385        25560.000     26910.0             0.000        25560.000
# 828318             0.000         0.0               NaN              NaN
# 321206         30375.000     29592.0          3037.500        30375.000
# 367050             0.000         0.0               NaN              NaN
# 1320802            0.000         0.0               NaN              NaN
# 1364026        37386.000     40347.0             0.000        37386.000
#
#         WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# 441106                     TUESDAY                       15
# 737587                     TUESDAY                       10
# 154187                      MONDAY                       14
# 1056681                     FRIDAY                       16
# 1026385                    TUESDAY                       11
# 828318                     TUESDAY                       15
# 321206                    THURSDAY                       17
# 367050                      MONDAY                        6
# 1320802                   THURSDAY                       18
# 1364026                   THURSDAY                       11
#
#         FLAG_LAST_APPL_PER_CONTRACT  NFLAG_LAST_APPL_IN_DAY  \
# 441106                            Y                       1
# 737587                            Y                       1
# 154187                            Y                       1
# 1056681                           Y                       1
# 1026385                           Y                       1
# 828318                            Y                       1
# 321206                            Y                       1
# 367050                            Y                       1
# 1320802                           Y                       1
# 1364026                           Y                       1
#
#          RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  RATE_INTEREST_PRIVILEGED  \
# 441106            0.106854                    NaN                       NaN
# 737587            0.109051                    NaN                       NaN
# 154187                 NaN                    NaN                       NaN
# 1056681                NaN                    NaN                       NaN
# 1026385           0.000000                    NaN                       NaN
# 828318                 NaN                    NaN                       NaN
# 321206            0.101384                    NaN                       NaN
# 367050                 NaN                    NaN                       NaN
# 1320802                NaN                    NaN                       NaN
# 1364026           0.000000                    NaN                       NaN
#
#         NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  DAYS_DECISION  \
# 441106                     XAP             Approved           -869
# 737587                     XAP             Approved          -2666
# 154187                     XNA              Refused           -250
# 1056681                    XNA             Approved           -399
# 1026385                    XAP             Approved           -401
# 828318                     XNA             Canceled            -34
# 321206                     XAP             Approved          -2647
# 367050                     XNA             Canceled           -563
# 1320802                    XNA             Canceled            -68
# 1364026                    XAP             Approved           -158
#
#              NAME_PAYMENT_TYPE CODE_REJECT_REASON  NAME_TYPE_SUITE  \
# 441106   Cash through the bank                XAP    Unaccompanied
# 737587   Cash through the bank                XAP    Unaccompanied
# 154187                     XNA                 HC              NaN
# 1056681  Cash through the bank                XAP              NaN
# 1026385  Cash through the bank                XAP              NaN
# 828318                     XNA                XAP              NaN
# 321206   Cash through the bank                XAP  Spouse, partner
# 367050                     XNA                XAP              NaN
# 1320802                    XNA                XAP              NaN
# 1364026  Cash through the bank                XAP    Unaccompanied
#
#         NAME_CLIENT_TYPE   NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# 441106               New             Furniture            POS
# 737587               New           Audio/Video            POS
# 154187          Repeater                   XNA            XNA
# 1056681         Repeater                   XNA           Cash
# 1026385         Repeater  Consumer Electronics            POS
# 828318          Repeater                   XNA            XNA
# 321206               New                Mobile            POS
# 367050          Repeater                   XNA            XNA
# 1320802         Repeater                   XNA            XNA
# 1364026         Repeater                Mobile            POS
#
#         NAME_PRODUCT_TYPE                CHANNEL_TYPE  SELLERPLACE_AREA  \
# 441106                XNA                       Stone               250
# 737587                XNA            Regional / Local               260
# 154187                XNA     Credit and cash offices                -1
# 1056681            x-sell  Channel of corporate sales                -1
# 1026385               XNA                Country-wide                40
# 828318                XNA     Credit and cash offices                -1
# 321206                XNA                       Stone                11
# 367050                XNA              Contact center                 0
# 1320802               XNA     Credit and cash offices                -1
# 1364026               XNA                Country-wide                45
#
#          NAME_SELLER_INDUSTRY  CNT_PAYMENT NAME_YIELD_GROUP  \
# 441106              Furniture         24.0           middle
# 737587   Consumer electronics         10.0       low_normal
# 154187                    XNA          NaN              XNA
# 1056681                   XNA         12.0       low_normal
# 1026385  Consumer electronics          6.0           middle
# 828318                    XNA          NaN              XNA
# 321206           Connectivity         10.0             high
# 367050                    XNA          NaN              XNA
# 1320802                   XNA          NaN              XNA
# 1364026          Connectivity          8.0             high
#
#                     PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# 441106          POS other with interest            365243.0          -836.0
# 737587   POS household without interest            365243.0         -2635.0
# 154187                             Cash                 NaN             NaN
# 1056681                Cash X-Sell: low            365243.0          -369.0
# 1026385     POS household with interest            365243.0          -369.0
# 828318                             Cash                 NaN             NaN
# 321206         POS mobile with interest            365243.0         -2616.0
# 367050                             Cash                 NaN             NaN
# 1320802                            Cash                 NaN             NaN
# 1364026        POS mobile with interest            365243.0          -128.0
#
#          DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 441106                      -146.0         -146.0            -136.0
# 737587                     -2365.0        -2365.0           -2360.0
# 154187                         NaN            NaN               NaN
# 1056681                      -39.0          -39.0             -33.0
# 1026385                     -219.0         -369.0            -361.0
# 828318                         NaN            NaN               NaN
# 321206                     -2346.0        -2346.0           -2336.0
# 367050                         NaN            NaN               NaN
# 1320802                        NaN            NaN               NaN
# 1364026                       82.0       365243.0          365243.0
#
#          NFLAG_INSURED_ON_APPROVAL
# 441106                         0.0
# 737587                         0.0
# 154187                         NaN
# 1056681                        1.0
# 1026385                        0.0
# 828318                         NaN
# 321206                         1.0
# 367050                         NaN
# 1320802                        NaN
# 1364026                        1.0
# Previous Application data contains:
# 1670214 rows and 37 columns
# \Previous Application data information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
#  12  RATE_DOWN_PAYMENT            774370 non-null   float64
#  13  RATE_INTEREST_PRIMARY        5951 non-null     float64
#  14  RATE_INTEREST_PRIVILEGED     5951 non-null     float64
#  15  NAME_CASH_LOAN_PURPOSE       1670214 non-null  object
#  16  NAME_CONTRACT_STATUS         1670214 non-null  object
#  17  DAYS_DECISION                1670214 non-null  int64
#  18  NAME_PAYMENT_TYPE            1670214 non-null  object
#  19  CODE_REJECT_REASON           1670214 non-null  object
#  20  NAME_TYPE_SUITE              849809 non-null   object
#  21  NAME_CLIENT_TYPE             1670214 non-null  object
#  22  NAME_GOODS_CATEGORY          1670214 non-null  object
#  23  NAME_PORTFOLIO               1670214 non-null  object
#  24  NAME_PRODUCT_TYPE            1670214 non-null  object
#  25  CHANNEL_TYPE                 1670214 non-null  object
#  26  SELLERPLACE_AREA             1670214 non-null  int64
#  27  NAME_SELLER_INDUSTRY         1670214 non-null  object
#  28  CNT_PAYMENT                  1297984 non-null  float64
#  29  NAME_YIELD_GROUP             1670214 non-null  object
#  30  PRODUCT_COMBINATION          1669868 non-null  object
#  31  DAYS_FIRST_DRAWING           997149 non-null   float64
#  32  DAYS_FIRST_DUE               997149 non-null   float64
#  33  DAYS_LAST_DUE_1ST_VERSION    997149 non-null   float64
#  34  DAYS_LAST_DUE                997149 non-null   float64
#  35  DAYS_TERMINATION             997149 non-null   float64
#  36  NFLAG_INSURED_ON_APPROVAL    997149 non-null   float64
# dtypes: float64(15), int64(6), object(16)
# memory usage: 471.5+ MB
# None
#
# Statistical Summary of numerical columns:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# 50%    8.054100e+04      1.638000e+03     1.123200e+05
# 75%    2.164185e+05      7.740000e+03     2.340000e+05
# max    6.905160e+06      3.060045e+06     6.905160e+06
#
#        HOUR_APPR_PROCESS_START  NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  \
# count             1.670214e+06            1.670214e+06      774370.000000
# mean              1.248418e+01            9.964675e-01           0.079637
# std               3.334028e+00            5.932963e-02           0.107823
# min               0.000000e+00            0.000000e+00          -0.000015
# 25%               1.000000e+01            1.000000e+00           0.000000
# 50%               1.200000e+01            1.000000e+00           0.051605
# 75%               1.500000e+01            1.000000e+00           0.108909
# max               2.300000e+01            1.000000e+00           1.000000
#
#        RATE_INTEREST_PRIMARY  RATE_INTEREST_PRIVILEGED  DAYS_DECISION  \
# count            5951.000000               5951.000000   1.670214e+06
# mean                0.188357                  0.773503  -8.806797e+02
# std                 0.087671                  0.100879   7.790997e+02
# min                 0.034781                  0.373150  -2.922000e+03
# 25%                 0.160716                  0.715645  -1.300000e+03
# 50%                 0.189122                  0.835095  -5.810000e+02
# 75%                 0.193330                  0.852537  -2.800000e+02
# max                 1.000000                  1.000000  -1.000000e+00
#
#        SELLERPLACE_AREA   CNT_PAYMENT  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# count      1.670214e+06  1.297984e+06       997149.000000   997149.000000
# mean       3.139511e+02  1.605408e+01       342209.855039    13826.269337
# std        7.127443e+03  1.456729e+01        88916.115834    72444.869708
# min       -1.000000e+00  0.000000e+00        -2922.000000    -2892.000000
# 25%       -1.000000e+00  6.000000e+00       365243.000000    -1628.000000
# 50%        3.000000e+00  1.200000e+01       365243.000000     -831.000000
# 75%        8.200000e+01  2.400000e+01       365243.000000     -411.000000
# max        4.000000e+06  8.400000e+01       365243.000000   365243.000000
#
#        DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# count              997149.000000  997149.000000     997149.000000
# mean                33767.774054   76582.403064      81992.343838
# std                106857.034789  149647.415123     153303.516729
# min                 -2801.000000   -2889.000000      -2874.000000
# 25%                 -1242.000000   -1314.000000      -1270.000000
# 50%                  -361.000000    -537.000000       -499.000000
# 75%                   129.000000     -74.000000        -44.000000
# max                365243.000000  365243.000000     365243.000000
#
#        NFLAG_INSURED_ON_APPROVAL
# count              997149.000000
# mean                    0.332570
# std                     0.471134
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     1.000000
# max                     1.000000
#        NAME_CONTRACT_TYPE WEEKDAY_APPR_PROCESS_START  \
# count             1670214                    1670214
# unique                  4                          7
# top            Cash loans                    TUESDAY
# freq               747553                     255118
#
#        FLAG_LAST_APPL_PER_CONTRACT NAME_CASH_LOAN_PURPOSE  \
# count                      1670214                1670214
# unique                           2                     25
# top                              Y                    XAP
# freq                       1661739                 922661
#
#        NAME_CONTRACT_STATUS      NAME_PAYMENT_TYPE CODE_REJECT_REASON  \
# count               1670214                1670214            1670214
# unique                    4                      4                  9
# top                Approved  Cash through the bank                XAP
# freq                1036781                1033552            1353093
#
#        NAME_TYPE_SUITE NAME_CLIENT_TYPE NAME_GOODS_CATEGORY NAME_PORTFOLIO  \
# count           849809          1670214             1670214        1670214
# unique               7                4                  28              5
# top      Unaccompanied         Repeater                 XNA            POS
# freq            508970          1231261              950809         691011
#
#        NAME_PRODUCT_TYPE             CHANNEL_TYPE NAME_SELLER_INDUSTRY  \
# count            1670214                  1670214              1670214
# unique                 3                        8                   11
# top                  XNA  Credit and cash offices                  XNA
# freq             1063666                   719968               855720
#
#        NAME_YIELD_GROUP PRODUCT_COMBINATION
# count           1670214             1669868
# unique                5                  17
# top                 XNA                Cash
# freq             517215              285990

# %%
dup = prev_app.duplicated().sum()
print(f'Duplicate rows in previous application data: {dup}')
# Out:
# Duplicate rows in previous application data: 0

# %%
ms.plot_missing_percentage(prev_app)

# %%
gprice = prev_app.loc[(prev_app.AMT_GOODS_PRICE.isna()) & (prev_app.AMT_ANNUITY.isna() & (prev_app.CNT_PAYMENT.isna()))]
sns.countplot(x=gprice.NAME_CONTRACT_STATUS)
# Out:
# <Axes: xlabel='NAME_CONTRACT_STATUS', ylabel='count'>

# %%
# Drop missing values more than 40%
pa_semiclean = ms.dropnan(prev_app, 0.4)
pa_clean = pa_semiclean.fillna(0)

# %%
pa_clean.to_csv('cleaned_data/previous_application_cleaned.csv', index=False)
